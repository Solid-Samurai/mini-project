# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense

# %%
# Load dataset
water_usage = pd.read_csv('Water Usage/SOC Outlet-1/Table(1).csv',
                          usecols=["Date", "Time", "Device Name", "water_flow_in_cubic_meter"])

# Reverse order if needed
data = water_usage[::-1]

# Set index and ensure DateTime format
data["Timestamp"] = pd.to_datetime(data["Date"] + " " + data["Time"],format="%d/%m/%Y %H:%M:%S")
data["Rounded_Timestamp"] = data["Timestamp"].dt.round("6H")
#data = data.drop_duplicates(subset=["Rounded_Timestamp"], keep="first")  # Keep first occurrence
# Set the new Timestamp as index
data.set_index("Rounded_Timestamp", inplace=True)

# Drop the original "Date" and "Time" columns if no longer needed
data.drop(columns=["Date", "Time","Timestamp","Device Name"], inplace=True)


# Ensure daily frequency
data = data.resample("6H").mean() 

# Rename column
data.rename(columns={'water_flow_in_cubic_meter': 'Water_Consumption'}, inplace=True)
print(data.isna().sum())
data.interpolate(method="linear", inplace=True)
# Display first 20 rows
print(data.head(20))
data.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Load dataset
# ----> 2 water_usage = pd.read_csv('Water Usage/SOC Outlet-1/Table(1).csv',
#       3                           usecols=["Date", "Time", "Device Name", "water_flow_in_cubic_meter"])
#       5 # Reverse order if needed
#       6 data = water_usage[::-1]
#
# File ~\Python\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\Python\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\Python\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\Python\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\Python\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Water Usage/SOC Outlet-1/Table(1).csv'

# %%
# Normalize the water consumption data
scaler = MinMaxScaler(feature_range=(0, 1))
data["Water_Consumption"] = scaler.fit_transform(data[["Water_Consumption"]])
original_timestamps = data.index  # Save timestamps before preprocessing
# Convert data to NumPy array
data_values = data["Water_Consumption"].values

# %%
def create_sequences(data, time_steps=10):
    """ Convert data into sequences of past `time_steps` readings as input (X) and the next reading as target (y). """
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i : i + time_steps])  # Past `time_steps` values as input
        y.append(data[i + time_steps])      # Predict next value

    X, y = np.array(X), np.array(y)

    # ✅ Ensure 3D shape: (samples, time_steps, features=1)
    X = X.reshape((X.shape[0], X.shape[1], 1))

    return X, y

# Define time steps (e.g., past 10 readings)
time_steps = 5
X, y = create_sequences(data_values, time_steps)

# Print shape (should be 3D: samples, time_steps, 1)
print("X shape:", X.shape)  # (num_samples, time_steps, 1)
print("y shape:", y.shape)  # (num_samples,)
# Out:
# X shape: (1460, 5, 1)
# y shape: (1460,)

# %%
# Define split index (80% training, 20% testing)
train_size = int(len(X) * 0.8)

# Split into training and testing sets
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Verify final shapes
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (1168, 5, 1), y_train shape: (1168,)
# X_test shape: (292, 5, 1), y_test shape: (292,)

# %%
# Build GRU Model
model = Sequential([
    GRU(50, return_sequences=True, input_shape=(time_steps, 1)),  # GRU layer with 50 neurons
    GRU(50, return_sequences=False),  # Second GRU layer
    Dense(25),  # Fully connected layer
    Dense(1)    # Output layer (predict next water consumption value)
])

# Compile Model
model.compile(optimizer="adam", loss="mean_squared_error")

# Train Model
history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# C:\Users\tamil\Python\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0478 - val_loss: 4.5980e-04
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2150e-05 - val_loss: 3.2967e-05
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.5618e-06 - val_loss: 2.6096e-05
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.9360e-06 - val_loss: 1.5489e-05
# Epoch 5/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.8144e-06 - val_loss: 3.1682e-05
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.0743e-06 - val_loss: 1.9896e-05
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.6726e-06 - val_loss: 1.5322e-05
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5078e-06 - val_loss: 2.7703e-05
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.0549e-06 - val_loss: 2.4826e-05
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.8948e-06 - val_loss: 1.4812e-05
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.8744e-06 - val_loss: 8.6856e-06
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.9341e-06 - val_loss: 2.0701e-05
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.7799e-06 - val_loss: 1.0778e-05
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.7872e-06 - val_loss: 1.5266e-05
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.4572e-06 - val_loss: 1.6983e-05
# Epoch 16/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.1737e-06 - val_loss: 7.0784e-06
# Epoch 17/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.4834e-06 - val_loss: 1.1417e-05
# Epoch 18/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3506e-06 - val_loss: 1.6372e-05
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.6827e-06 - val_loss: 6.6046e-06
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4552e-06 - val_loss: 8.5237e-06
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.4638e-06 - val_loss: 5.2856e-06
# Epoch 22/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.6824e-06 - val_loss: 9.7118e-06
# Epoch 23/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.5026e-06 - val_loss: 6.9609e-06
# Epoch 24/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.7542e-06 - val_loss: 2.3774e-05
# Epoch 25/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.0097e-06 - val_loss: 1.8489e-05
# Epoch 26/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.0814e-06 - val_loss: 4.9825e-06
# Epoch 27/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.8656e-06 - val_loss: 1.1590e-06
# Epoch 28/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.9852e-06 - val_loss: 2.9181e-06
# Epoch 29/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.8227e-06 - val_loss: 1.4037e-05
# Epoch 30/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.0472e-06 - val_loss: 1.4569e-06
# Epoch 31/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6258e-06 - val_loss: 2.7686e-06
# Epoch 32/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.7210e-06 - val_loss: 8.9772e-06
# Epoch 33/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.8517e-06 - val_loss: 1.9906e-05
# Epoch 34/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8341e-06 - val_loss: 3.4587e-06
# Epoch 35/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.5707e-06 - val_loss: 8.8731e-07
# Epoch 36/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.7669e-06 - val_loss: 7.6724e-06
# Epoch 37/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.1282e-06 - val_loss: 6.2770e-06
# Epoch 38/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1461e-06 - val_loss: 2.0954e-05
# Epoch 39/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8253e-06 - val_loss: 1.5976e-05
# Epoch 40/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.3572e-06 - val_loss: 1.0893e-05
# Epoch 41/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0301e-06 - val_loss: 4.7528e-06
# Epoch 42/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.7645e-06 - val_loss: 1.3312e-06
# Epoch 43/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.2142e-06 - val_loss: 2.3048e-06
# Epoch 44/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.9542e-06 - val_loss: 1.4465e-05
# Epoch 45/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.7330e-06 - val_loss: 1.0280e-05
# Epoch 46/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.9637e-06 - val_loss: 3.2417e-05
# Epoch 47/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.2063e-06 - val_loss: 3.2750e-06
# Epoch 48/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9792e-06 - val_loss: 6.4433e-07
# Epoch 49/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.2052e-06 - val_loss: 9.3312e-07
# Epoch 50/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5307e-06 - val_loss: 1.3247e-05

# %%
# Predict on test data
predictions = model.predict(X_test)

# Reverse scaling to get actual values
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step

# %%
from sklearn.metrics import mean_squared_error
predicted_timestamps = original_timestamps[-len(predictions):]  # Match predictions with time

# Compute RMSE
rmse = np.sqrt(mean_squared_error(y_test_actual, predictions))
print(f"Test RMSE: {rmse:.2f}")

# Plot results
plt.figure(figsize=(10, 5))
plt.plot(predicted_timestamps,y_test_actual, label="Actual Water Demand")
plt.plot(predicted_timestamps,predictions, label="Predicted Water Demand", linestyle="dashed")
plt.legend()
plt.xlabel("Time")
plt.ylabel("Water Consumption")
plt.title("GRU Water Demand Forecasting")
plt.show()
# Out:
# Test RMSE: 0.00
