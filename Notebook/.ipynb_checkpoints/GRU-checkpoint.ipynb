# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta

# %%
# Load dataset
water_usage = pd.read_csv('Water Usage/SOC Outlet-1/Table.csv',
                          usecols=["Date", "Time", "Device Name", "water_flow_in_cubic_meter"])

# Reverse order if needed
data = water_usage[::-1]


#data = data.drop_duplicates(subset=["Date"], keep="first")  # Keep first occurrence

# Set index and ensure DateTime format
data["Timestamp"] = pd.to_datetime(data["Date"] + " " + data["Time"],format="%d-%m-%Y %H:%M:%S")
data["Rounded_Timestamp"] = data["Timestamp"].dt.round("6H")

# Set the new Timestamp as index
data.set_index("Rounded_Timestamp", inplace=True)

# Drop the original "Date" and "Time" columns if no longer needed
data.drop(columns=["Date", "Time","Timestamp","Device Name"], inplace=True)


# Ensure daily frequency
data = data.resample("6H").mean() 

# Rename column
data.rename(columns={'water_flow_in_cubic_meter': 'Water_Consumption'}, inplace=True)
print(data.isna().sum())
data.interpolate(method="linear", inplace=True)
# Display first 20 rows
print(data.head(20))
data.plot()
# Out:
# C:\Users\tamil\AppData\Local\Temp\ipykernel_11288\2436670580.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Timestamp"] = pd.to_datetime(data["Date"] + " " + data["Time"],format="%d-%m-%Y %H:%M:%S")
# C:\Users\tamil\AppData\Local\Temp\ipykernel_11288\2436670580.py:13: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   data["Rounded_Timestamp"] = data["Timestamp"].dt.round("6H")
# C:\Users\tamil\AppData\Local\Temp\ipykernel_11288\2436670580.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Rounded_Timestamp"] = data["Timestamp"].dt.round("6H")
# C:\Users\tamil\AppData\Local\Temp\ipykernel_11288\2436670580.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=["Date", "Time","Timestamp","Device Name"], inplace=True)
# C:\Users\tamil\AppData\Local\Temp\ipykernel_11288\2436670580.py:23: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   data = data.resample("6H").mean()
# Water_Consumption    109
# dtype: int64
#                      Water_Consumption
# Rounded_Timestamp
# 2024-01-01 00:00:00            1214.70
# 2024-01-01 06:00:00            1214.70
# 2024-01-01 12:00:00            1214.70
# 2024-01-01 18:00:00            1214.70
# 2024-01-02 00:00:00            1214.70
# 2024-01-02 06:00:00            1214.70
# 2024-01-02 12:00:00            1215.30
# 2024-01-02 18:00:00            1220.10
# 2024-01-03 00:00:00            1220.10
# 2024-01-03 06:00:00            1222.50
# 2024-01-03 12:00:00            1232.00
# 2024-01-03 18:00:00            1240.10
# 2024-01-04 00:00:00            1246.55
# 2024-01-04 06:00:00            1248.60
# 2024-01-04 12:00:00            1254.50
# 2024-01-04 18:00:00            1261.00
# 2024-01-05 00:00:00            1265.00
# 2024-01-05 06:00:00            1267.90
# 2024-01-05 12:00:00            1273.30
# 2024-01-05 18:00:00            1280.20
# <Axes: xlabel='Rounded_Timestamp'>

# %%
# Normalize the water consumption data
scaler = MinMaxScaler(feature_range=(0, 1))
data["Water_Consumption"] = scaler.fit_transform(data[["Water_Consumption"]])
original_timestamps = data.index  # Save timestamps before preprocessing
# Convert data to NumPy array
data_values = data["Water_Consumption"].values

# %%
def create_sequences(data, time_steps=10):
    """ Convert data into sequences of past `time_steps` readings as input (X) and the next reading as target (y). """
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i : i + time_steps])  # Past `time_steps` values as input
        y.append(data[i + time_steps])      # Predict next value

    X, y = np.array(X), np.array(y)

    # ✅ Ensure 3D shape: (samples, time_steps, features=1)
    X = X.reshape((X.shape[0], X.shape[1], 1))

    return X, y

# Define time steps (e.g., past 10 readings)
time_steps = 7
X, y = create_sequences(data_values, time_steps)

# Print shape (should be 3D: samples, time_steps, 1)
print("X shape:", X.shape)  # (num_samples, time_steps, 1)
print("y shape:", y.shape)  # (num_samples,)
# Out:
# X shape: (1458, 7, 1)
# y shape: (1458,)

# %%
# Define split index (80% training, 20% testing)
train_size = int(len(X) * 0.8)

# Split into training and testing sets
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Verify final shapes
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (1166, 7, 1), y_train shape: (1166,)
# X_test shape: (292, 7, 1), y_test shape: (292,)

# %%
# Build GRU Model
def build_gru_model(optimizer):
    model = Sequential([
        GRU(50, activation='linear', return_sequences=True, input_shape=(7, 1)),
        GRU(50, activation='linear'),
        Dense(1)
    ])
    model.compile(optimizer=optimizer, loss='mse')
    return model

# %%
optimizers = {
    "Adam": Adam(learning_rate=0.001),
    "SGD": SGD(learning_rate=0.001, momentum=0.9),
    "RMSprop": RMSprop(learning_rate=0.0001),
    "Adagrad": Adagrad(learning_rate=0.001),
    "Adadelta": Adadelta(learning_rate=0.001)
}

# %%
import matplotlib.pyplot as plt

def plot_training_loss(history, model_name):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'{model_name} Training Loss')
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score

# Predict on test data
def pred(model, X_test, y_test, scaler, original_timestamps):
    predictions = model.predict(X_test)
    
    # Reverse scaling
    predictions = scaler.inverse_transform(predictions)
    y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
    predicted_timestamps = original_timestamps[-len(predictions):]  # Match predictions with time
    # Compute RMSE
    rmse = np.sqrt(mean_squared_error(y_test_actual, predictions))
    r2 = r2_score(y_test_actual, predictions)
    print(f"Test RMSE: {rmse:.2f}\n r2-score (closer to 1, more the model is preferred) : {r2}")
    #acc=100*(1-(rmse/len(y_test)))
    #print(f'Accuracy (ARIMA): {acc}')
    # Plot results
    plt.figure(figsize=(10, 5))
    plt.plot(predicted_timestamps,y_test_actual, label="Actual Water Demand")
    plt.plot(predicted_timestamps,predictions, label="Predicted Water Demand", linestyle="dashed")
    plt.legend()
    plt.xlabel("Time")
    plt.ylabel("Water Consumption")
    plt.title("GRU Water Demand Forecasting")
    metrics_text = f"RMSE: {rmse:.2f}\nR² Score: {r2:.2f}"
    plt.text(0.05, 0.7, metrics_text, transform=plt.gca().transAxes, fontsize=12,
             bbox=dict(facecolor='white', alpha=0.8, edgecolor='black'))
    plt.show()

# %%
for name, opt in optimizers.items():
    print(f"\nTraining GRU with {name} optimizer...")
    gru_model = build_gru_model(opt)
    history_gru = gru_model.fit(X_train, y_train, 
                              epochs=50, 
                              batch_size=32, 
                              validation_data=(X_test, y_test), 
                              verbose=1)
    # Plot for LSTM
    plot_training_loss(history_gru, "GRU")
    pred(gru_model,X_test,y_test,scaler,original_timestamps)
# Out:
# Training GRU with Adam optimizer...
# C:\Users\tamil\Python\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0866 - val_loss: 0.0067
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0020 - val_loss: 2.6143e-04
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.2412e-05 - val_loss: 1.4252e-05
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.0884e-06 - val_loss: 1.5910e-06
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6016e-06 - val_loss: 1.8022e-06
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.5724e-06 - val_loss: 1.4599e-06
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.5856e-06 - val_loss: 1.7512e-06
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5123e-06 - val_loss: 1.6576e-06
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2777e-06 - val_loss: 1.4034e-06
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.8363e-06 - val_loss: 1.4380e-06
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6558e-06 - val_loss: 1.9508e-06
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3634e-06 - val_loss: 1.3903e-06
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.6629e-06 - val_loss: 1.5062e-06
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.4510e-06 - val_loss: 1.5514e-06
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.6400e-06 - val_loss: 1.5995e-06
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.7614e-06 - val_loss: 1.3891e-06
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4059e-06 - val_loss: 1.3776e-06
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.7997e-06 - val_loss: 1.7048e-06
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.3924e-06 - val_loss: 1.4150e-06
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.6169e-06 - val_loss: 3.0837e-06
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.5414e-06 - val_loss: 3.1694e-06
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.8524e-06 - val_loss: 1.3636e-06
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.6973e-06 - val_loss: 1.5484e-06
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.6783e-06 - val_loss: 1.3879e-06
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.6179e-06 - val_loss: 1.3172e-06
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.4937e-06 - val_loss: 4.0340e-06
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.9008e-06 - val_loss: 1.2846e-06
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4649e-06 - val_loss: 1.3332e-06
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3734e-06 - val_loss: 1.3975e-06
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.5339e-06 - val_loss: 1.5838e-06
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.7083e-06 - val_loss: 2.1326e-06
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.8061e-06 - val_loss: 2.0884e-06
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.6192e-06 - val_loss: 2.6826e-06
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.6806e-06 - val_loss: 1.2893e-06
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.5181e-06 - val_loss: 1.2512e-06
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.6259e-06 - val_loss: 2.3154e-06
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.5909e-06 - val_loss: 1.3964e-06
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.7820e-06 - val_loss: 1.4028e-06
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4999e-06 - val_loss: 4.0769e-06
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.0690e-06 - val_loss: 1.6396e-06
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.7288e-06 - val_loss: 1.7497e-06
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.6095e-06 - val_loss: 1.6015e-06
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.6163e-06 - val_loss: 1.2330e-06
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.1121e-06 - val_loss: 1.3468e-06
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4861e-06 - val_loss: 1.3818e-06
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.5426e-06 - val_loss: 1.8982e-06
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.5058e-06 - val_loss: 1.4001e-06
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.1782e-06 - val_loss: 2.3465e-06
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.5886e-06 - val_loss: 2.9056e-06
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.1064e-06 - val_loss: 1.9160e-06
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# Test RMSE: 4.82
#  r2-score (closer to 1, more the model is preferred) : 0.9988751979725347
# Training GRU with SGD optimizer...
# Epoch 1/50
# C:\Users\tamil\Python\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 0.