# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta

# %%
# Load dataset
water_usage = pd.read_csv('Water Usage/SOC Outlet-1/Table.csv',
                          usecols=["Date", "Time", "Device Name", "water_flow_in_cubic_meter"])

# Reverse order if needed
data = water_usage[::-1]


#data = data.drop_duplicates(subset=["Date"], keep="first")  # Keep first occurrence

# Set index and ensure DateTime format
data["Timestamp"] = pd.to_datetime(data["Date"] + " " + data["Time"],format="%d-%m-%Y %H:%M:%S")
data["Rounded_Timestamp"] = data["Timestamp"].dt.round("6H")

# Set the new Timestamp as index
data.set_index("Rounded_Timestamp", inplace=True)

# Drop the original "Date" and "Time" columns if no longer needed
data.drop(columns=["Date", "Time","Timestamp","Device Name"], inplace=True)


# Ensure daily frequency
data = data.resample("6H").mean() 

# Rename column
data.rename(columns={'water_flow_in_cubic_meter': 'Water_Consumption'}, inplace=True)
print(data.isna().sum())
data.interpolate(method="linear", inplace=True)
# Display first 20 rows
print(data.head(20))
data.plot()
# Out:
# Water_Consumption    109
# dtype: int64
#                      Water_Consumption
# Rounded_Timestamp
# 2024-01-01 00:00:00            1214.70
# 2024-01-01 06:00:00            1214.70
# 2024-01-01 12:00:00            1214.70
# 2024-01-01 18:00:00            1214.70
# 2024-01-02 00:00:00            1214.70
# 2024-01-02 06:00:00            1214.70
# 2024-01-02 12:00:00            1215.30
# 2024-01-02 18:00:00            1220.10
# 2024-01-03 00:00:00            1220.10
# 2024-01-03 06:00:00            1222.50
# 2024-01-03 12:00:00            1232.00
# 2024-01-03 18:00:00            1240.10
# 2024-01-04 00:00:00            1246.55
# 2024-01-04 06:00:00            1248.60
# 2024-01-04 12:00:00            1254.50
# 2024-01-04 18:00:00            1261.00
# 2024-01-05 00:00:00            1265.00
# 2024-01-05 06:00:00            1267.90
# 2024-01-05 12:00:00            1273.30
# 2024-01-05 18:00:00            1280.20
# C:\Users\tamil\AppData\Local\Temp\ipykernel_9680\2436670580.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Timestamp"] = pd.to_datetime(data["Date"] + " " + data["Time"],format="%d-%m-%Y %H:%M:%S")
# C:\Users\tamil\AppData\Local\Temp\ipykernel_9680\2436670580.py:13: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   data["Rounded_Timestamp"] = data["Timestamp"].dt.round("6H")
# C:\Users\tamil\AppData\Local\Temp\ipykernel_9680\2436670580.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Rounded_Timestamp"] = data["Timestamp"].dt.round("6H")
# C:\Users\tamil\AppData\Local\Temp\ipykernel_9680\2436670580.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=["Date", "Time","Timestamp","Device Name"], inplace=True)
# C:\Users\tamil\AppData\Local\Temp\ipykernel_9680\2436670580.py:23: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   data = data.resample("6H").mean()
# <Axes: xlabel='Rounded_Timestamp'>

# %%
# Normalize the water consumption data
scaler = MinMaxScaler(feature_range=(0, 1))
data["Water_Consumption"] = scaler.fit_transform(data[["Water_Consumption"]])
original_timestamps = data.index  # Save timestamps before preprocessing
# Convert data to NumPy array
data_values = data["Water_Consumption"].values

# %%
def create_sequences(data, time_steps=10):
    """ Convert data into sequences of past `time_steps` readings as input (X) and the next reading as target (y). """
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i : i + time_steps])  # Past `time_steps` values as input
        y.append(data[i + time_steps])      # Predict next value

    X, y = np.array(X), np.array(y)

    # ✅ Ensure 3D shape: (samples, time_steps, features=1)
    X = X.reshape((X.shape[0], X.shape[1], 1))

    return X, y

# Define time steps (e.g., past 10 readings)
time_steps = 7
X, y = create_sequences(data_values, time_steps)

# Print shape (should be 3D: samples, time_steps, 1)
print("X shape:", X.shape)  # (num_samples, time_steps, 1)
print("y shape:", y.shape)  # (num_samples,)
# Out:
# X shape: (1458, 7, 1)
# y shape: (1458,)

# %%
# Define split index (80% training, 20% testing)
train_size = int(len(X) * 0.8)

# Split into training and testing sets
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Verify final shapes
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (1166, 7, 1), y_train shape: (1166,)
# X_test shape: (292, 7, 1), y_test shape: (292,)

# %%
# Build GRU Model
import tensorflow as tf
from tensorflow.keras.layers import SimpleRNN, Dense

def build_rnn_model():
    model = Sequential([
        tf.keras.layers.Flatten(input_shape=(7, 1)),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(1)
    ])

    model.compile(optimizer='adam', loss='mse')
    return model

# %%
import matplotlib.pyplot as plt

def plot_training_loss(history, model_name):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'{model_name} Training Loss')
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score

# Predict on test data
def pred(model, X_test, y_test, scaler, original_timestamps):
    predictions = model.predict(X_test)
    
    # Reverse scaling
    predictions = scaler.inverse_transform(predictions)
    y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
    predicted_timestamps = original_timestamps[-len(predictions):]  # Match predictions with time
    # Compute RMSE
    rmse = np.sqrt(mean_squared_error(y_test_actual, predictions))
    r2 = r2_score(y_test_actual, predictions)
    print(f"Test RMSE: {rmse:.2f}\n r2-score (closer to 1, more the model is preferred) : {r2}")
    #acc=100*(1-(rmse/len(y_test)))
    #print(f'Accuracy (ARIMA): {acc}')
    # Plot results
    plt.figure(figsize=(10, 5))
    plt.plot(predicted_timestamps,y_test_actual, label="Actual Water Demand")
    plt.plot(predicted_timestamps,predictions, label="Predicted Water Demand", linestyle="dashed")
    plt.legend()
    plt.xlabel("Time")
    plt.ylabel("Water Consumption")
    plt.title("RNN Water Demand Forecasting")
    metrics_text = f"RMSE: {rmse:.2f}\nR² Score: {r2:.2f}"
    plt.text(0.05, 0.7, metrics_text, transform=plt.gca().transAxes, fontsize=12,
             bbox=dict(facecolor='white', alpha=0.8, edgecolor='black'))
    plt.show()

# %%
    print(f"\nTraining RNN with adam optimizer...")
    rnn_model = build_rnn_model()
    history_rnn = rnn_model.fit(X_train, y_train, 
                              epochs=50, 
                              batch_size=32, 
                              validation_data=(X_test, y_test), 
                              verbose=1)
    # Plot for LSTM
    plot_training_loss(history_rnn, "RNN")
    pred(rnn_model,X_test,y_test,scaler,original_timestamps)
# Out:
# Training RNN with adam optimizer...
# C:\Users\tamil\Python\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1177 - val_loss: 0.0115
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - val_loss: 7.7867e-05
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4073e-05 - val_loss: 2.4435e-05
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3813e-06 - val_loss: 1.0650e-05
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2228e-06 - val_loss: 2.0972e-05
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4501e-06 - val_loss: 9.6738e-06
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2065e-06 - val_loss: 4.2797e-06
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4631e-06 - val_loss: 1.3259e-06
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0157e-06 - val_loss: 4.6806e-06
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4727e-06 - val_loss: 1.5418e-05
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7660e-06 - val_loss: 2.4564e-06
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9859e-06 - val_loss: 3.7832e-06
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3916e-06 - val_loss: 1.3910e-05
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6871e-06 - val_loss: 3.4817e-06
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5300e-06 - val_loss: 2.9758e-05
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1431e-06 - val_loss: 1.1729e-05
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2510e-06 - val_loss: 3.1058e-06
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9798e-06 - val_loss: 1.1432e-06
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3366e-06 - val_loss: 1.1983e-06
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3460e-06 - val_loss: 1.8949e-06
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0698e-06 - val_loss: 3.2204e-06
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2332e-06 - val_loss: 4.0495e-06
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1412e-06 - val_loss: 2.0456e-06
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0360e-06 - val_loss: 2.0971e-06
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0208e-06 - val_loss: 1.5232e-06
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3694e-06 - val_loss: 1.3356e-06
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5143e-06 - val_loss: 8.9306e-06
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6925e-06 - val_loss: 3.7955e-06
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8719e-06 - val_loss: 1.3597e-05
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5127e-06 - val_loss: 4.9194e-06
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9194e-06 - val_loss: 3.8875e-06
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3035e-06 - val_loss: 6.4666e-06
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4313e-06 - val_loss: 1.4467e-06
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5332e-06 - val_loss: 1.9780e-06
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7402e-06 - val_loss: 4.0420e-06
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4950e-06 - val_loss: 3.2095e-06
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7189e-06 - val_loss: 1.0141e-06
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2251e-06 - val_loss: 2.5644e-06
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5297e-06 - val_loss: 2.3491e-06
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0025e-06 - val_loss: 2.2146e-06
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1781e-06 - val_loss: 9.3885e-07
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2818e-06 - val_loss: 1.2029e-06
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0802e-06 - val_loss: 4.7164e-06
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3894e-06 - val_loss: 5.0766e-06
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9107e-06 - val_loss: 1.6327e-06
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6907e-06 - val_loss: 2.6167e-06
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6859e-06 - val_loss: 3.4875e-06
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9751e-06 - val_loss: 4.9649e-06
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4341e-06 - val_loss: 2.9811e-06
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4648e-06 - val_loss: 1.6578e-06
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Test RMSE: 4.48
#  r2-score (closer to 1, more the model is preferred) : 0.9990267944913196

# %%
# Save GRU model in Keras format
rnn_model.save("dense_model.keras")

# %%
import logging
tf.get_logger().setLevel(logging.ERROR)  # OR INFO for more detail

# %%
rnn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 7)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,877 (30.77 KB)
#  Trainable params: 2,625 (10.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 5,252 (20.52 KB)

# %%
import tensorflow as tf
# Convert to .tflite
converter = tf.lite.TFLiteConverter.from_keras_model(rnn_model)
tflite_model = converter.convert()
with open("dense_model.tflite", "wb") as f:
    f.write(tflite_model)
print("TFLite model saved as 'dense_model.tflite'")
# Out:
# Saved artifact at 'C:\Users\tamil\AppData\Local\Temp\tmpa998yohw'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   2318258320784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318258322704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318258322128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318258323088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318258322320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318258320976: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite model saved as 'dense_model.tflite'
